# %% [markdown]
# # Лабораторная работа №1 по дисциплине "Язык программирования Python"  (5 баллов)
# ## Тема: Переменные, типы данных, циклы, коллекции, модули
#
# **Выполните задания в указанных ячейках.**
# Каждое задание — отдельная программа.

# %% [markdown]
# ## Задание 1. Арифметические операции, ввод/вывод, форматируемые строки (0,5 балла)
#
# **Задача:**
#
# Напишите программу, которая:
# 1. Запрашивает у пользователя два целых числа.
# 2. Выполняет над этими числами 6 арифметических операций (+, -, *, /, %, //).
# 3. Выводит с помощью форматируемых строк результаты выполнения операций в следующем виде:<br>
# `6 + 13 = 19`<br>
# `6 - 13 = -7`<br>
# `6 * 13 = 78` <br>
# и т.д.<br>
# Вещественные значения должны выводиться с точностью 3 знака после десятичной точки.

# %%
# Место для решения задания 1

# %% [markdown]
# ## Задание 2. Арифметические операции, условный оператор (1 балл)
#
# **Задача:**
#
# Васе нужно снять в банкомате определенную сумму. В банкомате есть купюры номиналом 100, 200, 500, 1000 и 5000 рублей. Банкомат выдает деньги таким образом, чтобы количество купюр было минимальным. Посчитайте, сколько купюр каждого достоинства будет выдано Васе. Предусмотреть ситуацию, когда выдача данной суммы невозможна (например, 250 рублей).
# Вывести результаты в виде:<br>
# `Исходная сумма - 11500 рублей`
#  `5000 рублей - 2 купюры`
#  `1000 рублей - 1 купюра`
#  `500 рублей - 1 купюра`
#  Если какие-то купюры не выдавались, то их писать не нужно.

# %%
# Место для решения задания 2

# %% [markdown]
# ## Задание 3. Цикл с предусловием (1,5 балла)
#
# **Задача:**
#
# Управляемый РОБОТ тестируется в прямоугольном помещении размером N х M метров (N, M >= 10).  Начальное положение РОБОТА – точка с координатами (x,y). Оператор управляет РОБОТом командами:
# - север - N,
# - юг - S,
# - запад - W,
# - восток - E,
# - закончить -  X.
# После каждой команды РОБОТ перемещается на 1 метр в нужную сторону, и программа сообщает его новую позицию. Если РОБОТ упёрся в стену, то он не должен пытаться перемещаться в сторону стены, в этом случае его позиция не меняется. Нумерация идет снизу вверх и слева направо.
#
# Пример (размер комнаты 10х10):
# `[Программа]: Введите исходные координаты Робота (x,y):`
# `[Оператор]: 5`
# `[Оператор]: 9 `
# `[Программа]: Марсоход находится на позиции 5, 9, введите команду:`
# `[Оператор]: N`
# `[Программа]: Марсоход находится на позиции 5, 10, введите команду:`
# `[Оператор]: N`
# `[Программа]: Марсоход находится на позиции 5, 10, введите команду:`
# `[Оператор]: W`
# `[Программа]: Марсоход находится на позиции 4, 10, введите команду:`
# `[Оператор]: X`

# %%
# Место для решения задания 3

# %% [markdown]
# ## Задание 4. Цикл `for` и `while`(1 балл)
#
# **Задача:**
#
# С клавиатуры вводится N целых чисел. Если вводимое число имеет четную сумму цифр, то вывести это число и его сумму цифр. Посчитать, сколько таких чисел получилось.
# **Не использовать функции и списки!**

# %%
# Место для решения задания 4

# %% [markdown]
# ## Задание 5. Комбинированное: угадай число (1 балл)
#
# **Задача:**
#
# Компьютер загадывает случайное число от 1 до 100 (`random.randint`).
# Пользователь пытается угадать. Программа:
# - Даёт подсказки: "Больше", "Меньше".
# - Если угадал — поздравляет и завершает цикл (`break`).
# - Если пользователь ввёл `0` — программа завершается досрочно (`break` с сообщением "Выход по желанию").
# - Считает количество попыток.
# - После угадывания или выхода выводит число попыток и загаданное число.

# %%
# Место для решения задания 5
