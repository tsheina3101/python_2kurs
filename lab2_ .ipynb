# %% [markdown]
# # Лабораторная работа №2 по дисциплине "Язык программирования Python".
# # Тема: работа со списками, строками, функциями и исключениями
#
# ## Цель занятия
# Закрепить навыки работы с встроенными типами данных (list, tuple, str), освоить list comprehension, срезы, документирование функций и обработку исключений.
#
# **Общее время выполнения: 90 минут**

# %% [markdown]
# ## Задание 1. Списки и list comprehension (1 балл)
#
# **Темы:** списки, методы списков, list comprehension.

# %% [markdown]
# **Что нужно сделать:**
# Напишите программу, которая выполняет следующие действия:
# 1. Генерирует случайным образом список L1 из 20 элементов в диапазоне от -20 до 20 и выводит его на экран,
# 2. Формирует на основе этого списка новый список L2, в котором все отрицательные элементы будут удвоены, а из положительных чисел извлечен квадратный корень, и выводит его на экран (обязательно использовать List comprehension),
# 3. Вставляет перед каждым отрицательным элементом списка L1 число 0 и выводит список на экран (нельзя использовать дополнительный список!),
# 4. Удаляет из списка L1 все элементы с заданным значением K и выводит его на экран (нельзя использовать дополнительный список!), ,
# 5. Добавляет перед первым элементом списка L1 три нуля, в конец списка – три элемента с заданным  значением  Z и выводит список на экран (нельзя использовать дополнительный список!), ,
# 6. Сортирует список L1 по возрастанию и выводит его на экран

# %%
# Ваш код здесь

# %% [markdown]
# ## Задание 2. Кортежи. Строки (1 балл)
#
# **Темы:** кортежи, строки, срезы строк.

# %% [markdown]
# **Что нужно сделать:**
# 1. Создайте кортеж из 10 произвольных слов.
# 2. Напишите программу для игры "Анаграммы", которая будет случайным образом извлекать из кортежа слово, перемешивать буквы в этом слове и предлагать пользователю угадать заданное слово.На угадывание слова давать 3 попытки.

# %%
# Ваш код здесь

# %% [markdown]
# ## Задание 3. Функции  (3 балла)
#
# **Темы:** Функции: создание, параметры возврат значений, docstring

# %% [markdown]
# Вам необходимо написать несколько функций для обработки списка оценок студентов.

# %%
grades = [85, 92, 78, 90, 65, 88, 95, 70, 82, 100, 45, 76]

# %% [markdown]
# **Задачи:**
# 1. Функция calculate_statistics(grades_list)
# Принимает список оценок. Возвращает кортеж из 4 значений:
# - средний балл (округлённый до 2 знаков)
# - максимальная оценка
# - минимальная оценка
# - количество оценок
#
# Добавьте docstring с описанием параметра и возвращаемого значения.
#
# 2. Функция filter_grades(grades_list, threshold, above=True)
# Принимает список оценок, пороговое значение threshold и флаг above.
# Если above = True — возвращает список оценок выше или равных threshold.
# Если above = False — возвращает список оценок ниже threshold.
# Значение по умолчанию для above = True.
#
# Добавьте docstring.
#
# 3. Функция apply_bonus(grades_list, bonus_points)
# Принимает список оценок и количество бонусных баллов (целое число).
# Возвращает новый список, где к каждой оценке прибавлены бонусные баллы.
# Если результат превышает 100, оценка должна быть не больше 100.
# Используйте list comprehension внутри функции.
#
# Добавьте docstring.
#
# Напишите код, который:
# 1. Вызывает calculate_statistics и выводит статистику.
# 2. Вызывает filter_grades c параметрами threshold=80, above=False, выводит список оценок ниже 80.
# 3. Вызывает apply_bonus c параметрами bonus_points=5, выводит новый список с бонусом.

# %%
# Ваш код здесь
