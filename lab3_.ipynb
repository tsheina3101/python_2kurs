# %% [markdown]
# # Лабораторная работа №3 по дисциплине "Язык программирования Python".
#
# # Тема: словари и множества, файловый ввод/вывод. Модуль collection
#
# ## Цель занятия
# Закрепить навыки работы с коллекциями dict и set, обработки файлов в формате txt, csv, json, использование модуля collection
#
# **Общее время выполнения: 90 минут**

# %% [markdown]
# ## Задание 1. Словари, обработка файлов  (2 балла)
#
# **Темы:** словари, работа с файлами .

# %% [markdown]
# **Что нужно сделать:**
# В архиве voina-i-mir.zip лежит роман Льва Толстого «Война и мир». Напишите программу, которая подсчитает статистику по буквам (русского и латинского алфавита) в этом романе и выведет результат в текстовый файл. Результат должен быть отсортирован по частоте встречаемости букв (по возрастанию или   убыванию). Регистр символов имеет значение. Постарайтесь написать программу так, чтобы для её работы не требовалась распаковка  архива “вручную” (используйте модуль zipfile).
#
# Ответ должен быть в таком виде (доли от 1):
# `Й 0.00000126`
# `Z 0.00000253`
# `W 0.00000674`
# `Щ 0.00000716`
# `….`
# `и 0.06492206`
# `а 0.07803966`
# `е 0.07942622`
# `о 0.11040234`

# %%
# Ваш код здесь

# %% [markdown]
# ## Задание 2. Множества, словари, обработка файлов (3 балла)
#
# **Темы:** множества, словари, сортировка, работа с файлами в разных форматах

# %% [markdown]
# **Что нужно сделать:**
#
# Дан лог-файл server.log (текстовый), каждая строка содержит:
# `IP-адрес - - [дата] "REQUEST" код_ответа размер`
# Пример:
# `192.168.1.10 - - [20/Oct/2025:12:34:56] "GET /index.html" 200 1024`
#
# Написать программу, которая:
#
# - Собирает все уникальные IP-адреса, с которых были запросы.
# - Считает для каждого IP:
# - Общее количество запросов.
# - Количество неудачных запросов (код ответа >= 400).
# - Сортирует IP по убыванию доли неудачных запросов (если доля одинаковая — то по убыванию общего числа запросов).
# - Сохраняет в CSV-файл report.csv столбцы:
#
# `IP, Всего_запросов, Неудачных_запросов, Доля_ошибок (доля в процентах, округлённая до 1 знака).`
#
# - Выводит на экран топ-5 проблемных IP (по доле ошибок) в виде красивой таблицы.
#
# ![image.png](attachment:image.png)

# %%
# Ваш код здесь
